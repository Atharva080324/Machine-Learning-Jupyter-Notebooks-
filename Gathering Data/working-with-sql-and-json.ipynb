# %% [markdown]
# JSON IS USED WHERE A API IS PUT ON A SERVER. THE DATA GIVEN TO US FORM THE SERVER IS IN JSON FORMAT     .
# SQL => EXTRACTING DATA FORM DATABASES

# %%
import pandas as pd

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
#Using API 
pd.read_json('https://v6.exchangerate-api.com/v6/fc5f5a3f9532b78c48a0225a/latest/USD')
# Out:
#       result                          documentation  \
# USD  success  https://www.exchangerate-api.com/docs
# AED  success  https://www.exchangerate-api.com/docs
# AFN  success  https://www.exchangerate-api.com/docs
# ALL  success  https://www.exchangerate-api.com/docs
# AMD  success  https://www.exchangerate-api.com/docs
# ..       ...                                    ...
# XPF  success  https://www.exchangerate-api.com/docs
# YER  success  https://www.exchangerate-api.com/docs
# ZAR  success  https://www.exchangerate-api.com/docs
# ZMW  success  https://www.exchangerate-api.com/docs
# ZWL  success  https://www.exchangerate-api.com/docs
#
#                                terms_of_use  time_last_update_unix  \
# USD  https://www.exchangerate-api.com/terms             1741824001
# AED  https://www.exchangerate-api.com/terms             1741824001
# AFN  https://www.exchangerate-api.com/terms             1741824001
# ...

# %%
#Working With SQL

# %%
import mysql.connector         #import library

# %%
#WE NEED TO PASS 4 MANDATORY PARAMTERES THOSE ARE host,user,password,database
conn = mysql.connector.connect(host='localhost',user='root',password='',database='world') #create connection object
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File D:\New folder\Lib\site-packages\mysql\connector\network.py:509, in MySQLTCPSocket.open_connection(self)
#     508     self.sock.settimeout(self._connection_timeout)
# --> 509     self.sock.connect(sockaddr)
#     510 except IOError as err:
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# Cell In[35], line 2
#       1 #WE NEED TO PASS 4 MANDATORY PARAMTERES THOSE ARE host,user,password,database
# ----> 2 conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')
#
# File D:\New folder\Lib\site-packages\mysql\connector\__init__.py:179, in connect(*args, **kwargs)
# ...

# %%
pd.read_sql_query("SELECT * FROM countrylanguage",conn) #pass query using read_sql_query

# %%
#Reading data from API
import pandas as pd
import requests

# %%
response=requests.get('https://www.freetestapi.com/api/v1/movies') #pass api link to get function of requests

# %%
response.json()
# Out:
# [{'id': 1,
#   'title': 'The Shawshank Redemption',
#   'year': 1994,
#   'genre': ['Drama'],
#   'rating': 9.3,
#   'director': 'Frank Darabont',
#   'actors': ['Tim Robbins', 'Morgan Freeman'],
#   'plot': 'Two imprisoned men bond over several years, finding solace and eventual redemption through acts of common decency.',
#   'poster': 'https://fakeimg.pl/220x310/ff0000',
#   'trailer': 'https://example.com/shawshank_redemption_trailer.mp4',
#   'runtime': 142,
#   'awards': 'Nominated for 7 Oscars',
#   'country': 'USA',
#   'language': 'English',
#   'boxOffice': '$28.3 million',
#   'production': 'Columbia Pictures',
#   'website': 'http://www.warnerbros.com/movies/shawshank-redemption'},
#  {'id': 2,
#   'title': 'The Godfather',
#   'year': 1972,
#   'genre': ['Crime', 'Drama'],
#   'rating': 9.2,
#   'director': 'Francis Ford Coppola',
#   'actors': ['Marlon Brando', 'Al Pacino', 'James Caan'],
# ...

# %%
df = pd.DataFrame(response.json()).head()[['id','year','rating']] #Using pandas Dataframe

# %%
df
# Out:
#    id  year  rating
# 0   1  1994     9.3
# 1   2  1972     9.2
# 2   3  2008     9.0
# 3   4  1994     8.9
# 4   5  1994     8.8

# %%
df.to_csv('movies.csv') #when storing the json into a 
#dataframe convert it to csv file using df.to_csv('file_name.csv') function

# %%
df
# Out:
#    id  year  rating
# 0   1  1994     9.3
# 1   2  1972     9.2
# 2   3  2008     9.0
# 3   4  1994     8.9
# 4   5  1994     8.8
